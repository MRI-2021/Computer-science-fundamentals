# %% [markdown]
# <a href="https://colab.research.google.com/github/MRI-2021/Computer-science-fundamentals/blob/main/Python%20Pandas%20Machine%20Learning%20from%20data%20preparation%20to%20model%20deploiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Pandas Machine Learning from data preparation to model deploiment
import pandas as pd
url = 'https://raw.githubusercontent.com/a-forty-two/cylons/master/data.csv'
df = pd.read_csv (url)
df.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df = df.drop(['Unnamed: 32'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Generate a descriptive statistic report for dataset.
df.describe().T # Transpose if you have a lot of columns.
# Out:
#                          count          mean  ...           75%           max
# id                       569.0  3.037183e+07  ...  8.813129e+06  9.113205e+08
# radius_mean              569.0  1.412729e+01  ...  1.578000e+01  2.811000e+01
# texture_mean             569.0  1.928965e+01  ...  2.180000e+01  3.928000e+01
# perimeter_mean           569.0  9.196903e+01  ...  1.041000e+02  1.885000e+02
# area_mean                569.0  6.548891e+02  ...  7.827000e+02  2.501000e+03
# smoothness_mean          569.0  9.636028e-02  ...  1.053000e-01  1.634000e-01
# compactness_mean         569.0  1.043410e-01  ...  1.304000e-01  3.454000e-01
# concavity_mean           569.0  8.879932e-02  ...  1.307000e-01  4.268000e-01
# concave points_mean      569.0  4.891915e-02  ...  7.400000e-02  2.012000e-01
# symmetry_mean            569.0  1.811619e-01  ...  1.957000e-01  3.040000e-01
# fractal_dimension_mean   569.0  6.279761e-02  ...  6.612000e-02  9.744000e-02
# ...

# %%
# Correlation and visualisation to understand the data.
correlations = df.corr()
correlations
# Out:
#                                id  ...  fractal_dimension_worst
# id                       1.000000  ...                -0.029866
# radius_mean              0.074626  ...                 0.007066
# texture_mean             0.099770  ...                 0.119205
# perimeter_mean           0.073159  ...                 0.051019
# area_mean                0.096893  ...                 0.003738
# smoothness_mean         -0.012968  ...                 0.499316
# compactness_mean         0.000096  ...                 0.687382
# concavity_mean           0.050080  ...                 0.514930
# concave points_mean      0.044158  ...                 0.368661
# symmetry_mean           -0.022114  ...                 0.438413
# fractal_dimension_mean  -0.052511  ...                 0.767297
# radius_se                0.143048  ...                 0.049559
# texture_se              -0.007526  ...                -0.045655
# perimeter_se             0.137331  ...                 0.085433
# ...

# %%
import seaborn as sns
sns.heatmap(correlations, cmap='coolwarm')

# %%
# Model selection: choose algorithm/estimator e.g. Classification, Clustering, Regression, Dimensionality reduction.
df = df.set_index('id') # convert column "id" into index so it won't be considered in my model (it will take all columns but index).
df.head()
# Out:
#          diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# id                               ...
# 842302           M        17.99  ...          0.4601                  0.11890
# 842517           M        20.57  ...          0.2750                  0.08902
# 84300903         M        19.69  ...          0.3613                  0.08758
# 84348301         M        11.42  ...          0.6638                  0.17300
# 84358402         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
# Model selection: Label (y) and Features (x).
y = df.loc[:,['diagnosis']]
x = df.iloc[:,1:] # Input it is going to be all the columns in the dataset.

#y.head()
x.head()
# Out:
#           radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# id                                   ...
# 842302          17.99         10.38  ...          0.4601                  0.11890
# 842517          20.57         17.77  ...          0.2750                  0.08902
# 84300903        19.69         21.25  ...          0.3613                  0.08758
# 84348301        11.42         20.38  ...          0.6638                  0.17300
# 84358402        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
# Model selection: split dataset in Train and Test/Production datasets (Train should be bigger than Test).
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=42) # random_state is the seed to start the random sequence.

#xtrain.head()
#xtest.head()
#ytrain.head()
ytest.head()
# Out:
#        diagnosis
# id
# 87930          B
# 859575         M
# 8670           M
# 907915         B
# 921385         B

# %%
## Normalisation: calculate Z-score (standard deviations from the mean) 
## Assumptions for Z test is: samples from population are independent of each other, population is normally distributed.

## assumptions from Training data are applied to Testing data
stats = xtrain.describe().T

# Z-score
xmean = stats['mean']
xstd = stats['std']

# Z-score = (data - mean) / standard deviation
xtrain_z_norm = (xtrain-xmean)/xstd
xtest_z_norm = (xtest-xmean)/xstd

# Z-score normalise from -inf to +inf is >3 , instead <-3 means it is an outlier.
xtrain_z_norm.head()
# Out:
#           radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# id                                   ...
# 859471      -1.439169     -0.434841  ...        2.094936                 1.884376
# 873593       1.971926      1.731120  ...        1.889081                 2.495092
# 859196      -1.398443     -1.248248  ...        0.596945                 0.057831
# 88466802    -0.980717      1.414665  ...        0.798049                -0.134349
# 858970      -1.116471     -1.009149  ...        1.032407                -0.205506
#
# [5 rows x 30 columns]

# %%
## Min-max normalization (the minimum value of that feature gets transformed into a 0, the maximum value gets transformed into a 1)

## assumptions from Training data are applied to Testing data
stats = xtrain.describe().T

# Min-max
xmax = stats['max']
xmin = stats['min']

# Min-max = (data - min) / (max - min)
xtrain_mm_norm = (xtrain-xmin)/(xmax-xmin)
xtest_mm_norm = (xtest-xmin)/(xmax-xmin)

# values scaled from 0 to 1 
xtrain_mm_norm.head()
# Out:
#           radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# id                                   ...
# 859471       0.065527      0.257694  ...        0.524936                 0.529502
# 873593       0.656203      0.570172  ...        0.499310                 0.621906
# 859196       0.072579      0.140345  ...        0.338459                 0.253137
# 88466802     0.144914      0.524518  ...        0.363493                 0.224059
# 858970       0.121407      0.174839  ...        0.392667                 0.213293
#
# [5 rows x 30 columns]

# %%
# Normalising data: Machine Learning only happens with numbers, so I have to convert the B and M in "diagnosis" to 0 and 1.
## Encoding categorical features into numerical values.

ydic = {'M':1,'B':0}
ytrain_encoded = ytrain['diagnosis'].apply(lambda x: ydic[x])
ytest_encoded = ytest['diagnosis'].apply(lambda x: ydic[x])

ytrain_encoded.head()
#ytest_encoded.head()
# Out:
# id
# 859471      0
# 873593      1
# 859196      0
# 88466802    0
# 858970      0
# Name: diagnosis, dtype: int64

# %%
# # Normalising data: Machine Learning only happens with numbers, so I have to convert the B and M in "diagnosis" to 0 and 1.
# ## Encoding in Regression
# logic = {'M':1,'B':0}
# ytrain_encoded = ytrain['diagnosis'].map(lambda diag: logic[diag])
# ytest_encoded = ytest['diagnosis'].map(lambda diag: logic[diag])

# ytrain_encoded.head()
# #ytest_encoded.head()

# %%
# Import Models:
xtrain_norm = xtrain_z_norm # If we decide to use Z score.

from sklearn.ensemble import RandomForestClassifier # If we decide to use RandomForestClassifier.
model = RandomForestClassifier()
model.fit(xtrain_norm, ytrain_encoded)

# To Import several models using a loop.
# from sklearn.models ... import all ML models
#for loop: model.fit()
#    model.predict()
# Out:
# RandomForestClassifier()

# %%
# Import Models:
xtest_norm = xtest_z_norm # If we decide to use Z score.

ypred = model.predict(xtest_norm) # Prediction generated by the Model.
#ypred ## To visualise the whole array.
ypred[:10] # If the array is to big to be visualised.
# Out:
# array([0, 1, 1, 0, 0, 1, 1, 1, 1, 0])

# %%
# ## This is an example of another Model that can be imported.

# xtrain_norm = xtrain_z_norm
# xtest_norm = xtest_z_norm

# from sklearn.neighbors import KNeighborsClassifier
# model = KNeighborsClassifier()
# model.fit(xtrain_norm,ytrain_encoded)

# predictions = model.predict(xtest_norm)
# predictions

# %%
## Check statistical measures suitable for the model
## Classification metrics (Accuracy, Precision, Recall, F1 score)
## Regression metrics (MAE, RMSE, RAE, MZOE)

# Model Evaluation - Accuracy
from sklearn.metrics import accuracy_score
accuracy_m1 = accuracy_score(ypred,ytest_encoded) # m1 = because this is the first model I used to predict.
accuracy_m1
# Out:
# 0.9649122807017544

# %%
# Model Evaluation - Cross value score
from sklearn.model_selection import cross_val_score
csv_m1 = cross_val_score(model, xtrain_norm, ytrain_encoded, cv=5)
csv_m1
# Out:
# array([0.96703297, 0.95604396, 0.98901099, 0.96703297, 0.92307692])

# %%
# Model Deployment - Export model
import pickle
pickle.dump(model, open('model1.plk', 'wb'))

# %%
# Model Deployment - Consume code
import sklearn
print(sklearn.__version__)

# Azure ML workspace and ML studio
# register your model (we need sklearn version number)
# upload file, then deploy on web (pick "container"), consume code (in "endpoint").
# Out:
# 1.0.2

# %%
# Groupby and Agg example

# df_gb = df.groupby(['diagnosis'])
# df_agg = df_gb.agg({'concavity_mean':'size'})
# df_agg
