# %% [markdown]
# <a href="https://colab.research.google.com/github/MRI-2021/Computer-science-fundamentals/blob/main/Analysis%20member_activity_and_demographics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57c352a0-222b-44f9-b9fd-a3dc1a5d4b0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57c352a0-222b-44f9-b9fd-a3dc1a5d4b0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving member_activity.csv to member_activity (1).csv

# %%
import io
df1 = pd.read_csv(io.BytesIO(uploaded['member_activity.csv']))
# First dataset is now stored in a Pandas Dataframe

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f3f60406-3bd6-4b8a-ab82-4a0e72ddf90e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3f60406-3bd6-4b8a-ab82-4a0e72ddf90e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving member_demographics.csv to member_demographics (1).csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['member_demographics.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
print('\n============= HEAD ACTIVITY =============')
print(df1.head(3))
print('\n============= HEAD DEMOGRAPHIC =============')
print(df2.head(3))
# Out:
# ============= HEAD ACTIVITY =============
#    member_id  ftd  ftb  bet_5  acquisition_cost  bets_1_week  bets_4_weeks  \
# 0     868104    1    1      0          0.000000            2             2
# 1     868236    1    1      0         26.046512            3             3
# 2     868283    1    1      1          0.000000           10            16
#
#    retained_1_week  retained_4_weeks first_bet_category  deposits_12_weeks  \
# 0                0                 0       Horse Racing                1.0
# 1                0                 0           Football                1.0
# 2                1                 1           Football               16.0
#
#    deposit_amount_12_weeks  bets_12_weeks  stake_12_weeks  revenue_12_weeks
# 0                     20.0              2       19.999990         27.999986
# 1                     20.0              3      102.269891         27.991587
# 2                   1600.0             32     3135.739803      -1789.131460
#
# ...

# %%
df1_i = df1.set_index('member_id')
df1_i.sort_index(ascending=True)
# Out:
#            ftd  ftb  bet_5  acquisition_cost  bets_1_week  bets_4_weeks  \
# member_id
# 868041       1    1      1         12.328889           19            27
# 868045       1    0      0         29.556611            0             0
# 868048       0    0      0          0.000000            0             0
# 868049       0    0      0          0.000000            0             0
# 868050       0    0      0          0.000000            0             0
# ...        ...  ...    ...               ...          ...           ...
# 919271       1    1      1          0.000000           37            42
# 919281       0    0      0          0.000000            0             0
# 919288       0    0      0          0.000000            0             0
# 919289       1    1      0          0.000000            1             1
# 919292       0    0      0          0.000000            0             0
#
#            retained_1_week  retained_4_weeks first_bet_category  \
# member_id
# ...

# %%
df2_i = df2.set_index('member_id')
df2_i.sort_index(ascending=True)
# Out:
#                       signup_datetime  age member_type signup_source  \
# member_id
# 868041     2021-01-01 00:48:55.736467   20    Customer          Paid
# 868045     2021-01-01 01:37:51.653839   20    Customer     Affiliate
# 868048     2021-01-01 01:44:53.356374   46    Customer       Organic
# 868049     2021-01-01 01:45:33.428287   34    Customer       Organic
# 868050     2021-01-01 01:46:15.470817   30    Customer       Organic
# ...                               ...  ...         ...           ...
# 919271     2021-03-31 21:20:02.330705   37    Customer       Organic
# 919281     2021-03-31 22:08:04.841143   24    Customer       Organic
# 919288     2021-03-31 22:53:31.504273   43    Customer       Organic
# 919289     2021-03-31 22:56:49.742662   26    Customer       Organic
# 919292     2021-03-31 23:13:56.680136   31    Customer       Organic
#
#             signup_channel
# member_id
# 868041               Apple
# 868045     Odds Comparison
# 868048             Organic
# ...

# %%
df_j = pd.concat([df1_i, df2_i], axis=1)

# %%
# print('\n============= HEAD ACTIVITY & DEMOGRAPHIC =============')
# print(df_j.head(3))

df_j.sort_index(ascending=True)
# Out:
#            ftd  ftb  bet_5  acquisition_cost  bets_1_week  bets_4_weeks  \
# member_id
# 868041       1    1      1         12.328889           19            27
# 868045       1    0      0         29.556611            0             0
# 868048       0    0      0          0.000000            0             0
# 868049       0    0      0          0.000000            0             0
# 868050       0    0      0          0.000000            0             0
# ...        ...  ...    ...               ...          ...           ...
# 919271       1    1      1          0.000000           37            42
# 919281       0    0      0          0.000000            0             0
# 919288       0    0      0          0.000000            0             0
# 919289       1    1      0          0.000000            1             1
# 919292       0    0      0          0.000000            0             0
#
#            retained_1_week  retained_4_weeks first_bet_category  \
# member_id
# ...
